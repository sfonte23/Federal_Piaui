# %% [markdown]
# # Semana 03 - Python (Parte 1)
#
# 💻 A programação em Python desempenha um papel significativo e onipresente no complexo e dinâmico mundo do mercado financeiro. Com uma combinação única de legibilidade, flexibilidade e um ecossistema de bibliotecas poderoso, Python emergiu como a linguagem de escolha para muitos profissionais, instituições financeiras e empresas que buscam soluções eficazes e inovadoras para as demandas constantes desse setor. Atualmente, Python se estabeleceu como uma ferramenta indispensável para enfrentar os desafios complexos e em constante evolução do mercado financeiro.
#
#
# ---
#
#
#
# 📝 Algumas maneiras pelas quais a programação em Python é aplicada ao mercado financeiro:
#
#
# 1.   **Análise de Dados e Modelagem Quantitativa:** Python é amplamente utilizado para analisar e modelar dados financeiros, dispondo de bibliotecas especializadas em manipulação e análise de dados e ferramentas para modelagem quantitativa e análise de risco.
#
# 2.   **Algoritmos de Negociação:** Muitos algoritmos de negociação são implementados em Python. A linguagem oferece a flexibilidade necessária para criar estratégias de negociação automatizadas, backtesting e otimização de algoritmos.
#
# 3.   **Visualização de Dados:** Python permite criar gráficos e visualizações interativas que ajudam os profissionais financeiros a entender melhor os padrões e tendências do mercado.
#
# 4.   **Aprendizado de Máquina:** Python é uma escolha popular para o desenvolvimento de modelos de aprendizado de máquina aplicados a previsões de preços, risco de crédito, detecção de fraudes e outras áreas do mercado financeiro.
#
# 5.   **Finanças Quantitativas:** Python é uma linguagem preferida para a implementação de modelos matemáticos complexos usados em finanças quantitativas, como precificação de derivativos e análise estatística avançada.
#
# 6.   **APIs e Integração de Dados:** Python é frequentemente usado para interagir com APIs de fornecedores de dados financeiros, permitindo que os profissionais acessem informações atualizadas sobre preços, notícias e outros dados relevantes.
#
# 7.   **Desenvolvimento de Plataformas de Negociação e Investimento:** Empresas que oferecem plataformas de negociação online e serviços de investimento muitas vezes usam Python para desenvolver interfaces de usuário, backends e sistemas de gerenciamento de contas.
#
# 8.   **Análise de Risco e Modelagem Financeira:** Python é utilizado para modelar riscos financeiros, calcular métricas de desempenho de investimentos e realizar análises de sensibilidade em cenários econômicos diversos.
#
#
# ---

# %% [markdown]
# ##Considerações Iniciais
#
# 📝 Algumas premissas importantes sobre estética em linguagens de programação em geral são:
#
# *   Bonito é melhor que feio.
#
# *   Explícito é melhor que implícito.
#
# *   Simples é melhor que complexo.
#
# *   Complexo é melhor que complicado.
#
# *   Legibilidade faz diferença.
#
# 🎯 E representam os ideais pelos quais faremos nossos códigos (ou *scripts*).
#
# > 💬 Embora nós, humanos, programamos códigos para as máquinas entenderem, é de extrema importância que outros humanos também os compreendam.
#
#
#
# ---

# %% [markdown]
# ✔️ **DICAS VALIOSAS PARA QUALQUER LINGUAGEM DE PROGRAMAÇÃO**
#
#
#
# *   **Use (e abuse) de documentação:** Toda linguagem de programação possui formas para inserir um texto que não é interpretado pela máquina mas é essencial para comentar o que estamos fazendo ali;
#
# *   **Não use acentos**: Este é campo nebuloso e não vamos entrar muito em detalhes. Cada computador, dependendo da forma em que está configurado, pode entender a palavra `maçã` como `maÃ§Ã£` ou como `ma��`, por exemplo. Opte por `maca`;
#
# *   **Letras maiúsculas e minúsculas**: Praticamente todas as linguagens de programação distinguem letras maiúsculas e minúsculas. Por exemplo, `Inteligencia Artificial` $\neq$ `inteligencia artificial`. Tenha preferência para o uso geral de letras minusculas. Maiúsculas somente quando muito necessário;
#
# *   **Não use espaço para definição de objetos**: Espaços são extremamente importantes para a clareza (principalmente pelos humanos) de linhas de comando. No entanto, um objeto qualquer que se chama `inteligencia artificial` será compreendido como 2 objetos (`inteligencia` e `artificial`), ocasionando erros. Opte por `inteligencia_artificial`;
#
# *   **Inglês**: As mais importantes linguagens são documentadas em inglês. Dominar a leitura de textos em língua inglesa só facilitará seu desenvolvimento. Além disso, temos muitas palavras reservadas dentro de cada linguagem para simbolizar algum comando, por exemplo `True` (Verdadeiro) e `False` (Falso).
#
#
#
# ---

# %% [markdown]
# ##A Linguagem Python
#
# 🐍 Python é uma linguagem de programação para propósitos diversos e pode ser usada para um enorme leque de aplicações em diferentes áreas, desde o desenvolvimento *web* até o aprendizado de máquina. Além de versátil, esta linguagem é amigável para iniciantes. Por esses e outros fatores, trata-se de uma das linguagens de programação mais populares do mundo.
#
# > Embora Python (Píton em português) seja o gênero de serpentes da família *Pythonidae*, este nome foi dado em homenagem ao humorístico britânico *Monty Python* que fez sucesso na década de 1970.
#
# ![py.png](data:image/png;base64,...)
#
# Durante o aprendizado de programação, iniciantes podem encontrar alguma dificuldade ao tentar entender como uma determinada linguagem funciona, especialmente se ela é muito diferente do seu idioma nativo. Mas fique tranquilo(a)!
#
# Honrando sua distinção como uma das linguagens mais fáceis de se aprender, o Python tem sintaxe muito simples, com muitas palavras-chave em inglês. Ele foi projetado desde o início para ser uma linguagem concisa, de alta legibilidade e fácil compreensão. Por isso, o Python é muito mais amigável para iniciantes quando comparado à outras linguagens.
#
#
#
# ---

# %% [markdown]
# ##Tutorial
#
# Este (mini) tutorial o guiará para melhor compreensão da linguagem de programação Python, fazendo-o capaz de:
#
# 1.   Realizar cálculos simples utilizando operadores aritméticos e compreendendo a ordem das operações.
#
# 2.   Manipular diferentes tipos de dados, como números inteiros, números de ponto flutuante e strings.
#
# 3.   Realizar operações com tipos de dados, incluindo concatenação de strings e conversão entre tipos.
#
# 4.   Criar e utilizar funções personalizadas, compreendendo como definir argumentos e receber resultados.
#
# 5.   Compreender a importância da estética na programação, utilizando comentários para documentar o código e torná-lo mais legível.
#
# 6.   Estabelecer uma base sólida para explorar conceitos mais avançados e desenvolver aplicações mais complexas em Python com confiança e compreensão.
#
# ---

# %% [markdown]
# ###Calculadora
#
# Você pode utilizar o Python como uma grande calculadora:

# %%
6 + 3
# Out:
# 9

# %%
6 - 3
# Out:
# 3

# %%
6 * 3
# Out:
# 18

# %%
6 / 3
# Out:
# 2.0

# %% [markdown]
# Use (somente) parênteses para a realização de contas complexas como $$3 \times \{12 + [(3 + 2) - 5 \times 3] \times 5 \}:$$

# %%
3 * (12 + ((3 + 2) - 5 * 3) * 5)
# Out:
# -114

# %% [markdown]
# > ⚠️ O Python segue a ordem matemática das operações, priorizando a multiplicação (ou divisão) e depois, a adição (ou subtração)
#
# Os operadores aritméticos básicos disponíveis no Python são:

# %% [markdown]
# Operador | Conceito                      | Exemplo
# ---------|-------------------------------|----------
#    +     | Adição ou sinal positivo      | 13 + 7
#    -     | Subtração ou sinal negativo   | - 13 - 7
#    *     | Multiplicação                 | 3 * 4
#    /     | Divisão                       | 10 / 5
#    //    | Divisão inteira               | 10 // 6
#    %     | Módulo                        | 4 % 2
#    **    | Exponenciação                 | 4 ** 2
#
#
#
# ---

# %% [markdown]
# ###Objetos
#
# Podemos salvar as contas que fazemos em objetos que serão chamados de *variáveis*:

# %%
a = 6 + 3

b = 6 - 3

c = 6 * 3

d = 6 / 3

# %% [markdown]
# Para visualizá-los, basta utilizar o comando `print`:

# %%
print(a)
print(b)
# Out:
# 9
# 3

# %% [markdown]
# Considerando um objeto de cada vez:

# %%
a
# Out:
# 9

# %%
b
# Out:
# 3

# %% [markdown]
# > ⚠️ Eventualmente, usaremos formas diferente para cada tipo de situação!

# %% [markdown]
# Podemos ainda realizar operações quando os objetos (ou as variáveis) são do mesmo tipo. Ou seja, aqui ainda estamos tratando somente de números. Então, podemos fazer contas diretamente:

# %%
print(a + b)
print(3 * b)
print(3 * a + 2 * b + 5 * c + 4 * d)
# Out:
# 12
# 9
# 131.0

# %% [markdown]
# ---
#
#
# ###Tipos

# %% [markdown]
# ####Numéricos
#
# Quando tratamos de números no Python, internamente a máquina pode entendê-los de duas formas:
#
#
# *   `float`: Formato numérico com casas decimais. Ex.: `1` é entendido pelo computador como `1.00000000...`;
# *   `int`: Formato numérico sem casas decimais (inteiros). Ex.: `3.145` é entendido pelo computador como `3`.

# %%
a = float(29/5)
b = int(4.5)
c = int(3.9)

print(a)
print(b)
print(c)
# Out:
# 5.8
# 4
# 3

# %% [markdown]
# > ⚠️ O Python utiliza o padrão numérico estadunidense onde o símbolo para separar a parte inteira da decimal de um número é o **ponto** $(\cdot)$ (diferente do padrão brasileiro que utiliza **vírgula** $(,)$).

# %% [markdown]
# Cuidado ao somar esses 2 tipos:

# %%
print(a + b)
type(a + b)
# Out:
# 9.8
# float

# %% [markdown]
# ---
#
#
# ####Alfanuméricos
#
# O Python é muito poderoso e consegue lidar com outros tipos de dados além dos números. Temos disponíveis operadores *booleanos*. Os valores do tipo `bool` podem representar dois valores completamente distintos: `True` (igual ao `int 1`) e `False` (igual ao `int 0`) para, respectivamente, `verdadeiro` e `falso`:

# %%
operador_bool_verdadeiro = True
operador_bool_falso = False

# %% [markdown]
# > 🛑 A primeira letra é maiúscula! Ortografias distintas não são permitidas.

# %%
a = 3
b = 5

print(a > b)
print(a == (b - 2))
print((a * 5) != (b * 3))
# Out:
# False
# True
# False

# %% [markdown]
# ⚠️ **Não confunda** ⚠️
#
#
# *    `=` (símbolo de **atribuição**);
# *   `==` (símbolo de **igualdade**).

# %% [markdown]
# Por fim, temos o tipo `string` e é com ele que tratamos texto delimitando por aspas simples ou duplas (mas as aspas devem corresponder):

# %%
string_aspas_simples = 'mercado financeiro'
string_aspas_duplas = "mercado financeiro"

print(string_aspas_simples)
print(string_aspas_duplas)
# Out:
# mercado financeiro
# mercado financeiro

# %% [markdown]
# > ⚠️ Tome cuidado ao somar `strings` e `floats`. Veja o que acontece:

# %%
nome = 'Maria'
sobrenome = "Silva"
idade = 60

print(nome + sobrenome + idade)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-508b30f567b1> in <cell line: 5>()
#       3 idade = 60
#       4
# ----> 5 print(nome + sobrenome + idade)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Quando os tipos não são os mesmo, devemos usar o seguinte comando para correta impressão:

# %%
print(f"Nome completo: {nome} {sobrenome}. Idade: {idade}")
# Out:
# Nome completo: Maria Silva. Idade: 60

# %% [markdown]
# ---
#
#
#
# ###Documentação
#
# Fazemos a documentação diretamente no código utilizando comentários. Assim, nosso código fica mais legível para outros humanos. Além disso, os comentários também são úteis para fazer com que o computador não leia determinado bloco durante um teste, por exemplo. Em Python, os comentários são simbolizados pelo símbolo $\#$ e se estende até o fim de cada linha. Vamos documentar os blocos anteriores:

# %%
# Nome do cliente
nome = 'Maria'

# Sobrenome do cliente
sobrenome = "Silva"

# Idade do cliente
idade = 60        # valor numerico

# Imprimindo um texto na tela
print(f"Nome completo: {nome} {sobrenome}. Idade: {idade}")
# Out:
# Nome completo: Maria Silva. Idade: 60

# %% [markdown]
# ---
#
#
#
# ###Funções
#
# Uma função é uma regra que recebe entradas (que são **chamadas de argumentos**) e retorna uma saída correspondente. Embora não tenhamos mencionado, mas já utilizamos duas funções, são elas `print` e `type`. Mas podemos definir novas funções em Python usando `def`:

# %%
# Funcao que calcula o dobro de um numero
def dobro(x):
    """Insira aqui um texto documental (opcional) que
    explique o que a funcao faz. Por exemplo, esta funcao multiplica sua
    entrada por 2.
    """
    return x * 2

# Testando a nova funcao
print(dobro(5))
print(dobro(-5))
print(dobro(.5))
# Out:
# 10
# -10
# 1.0

# %% [markdown]
# > ⚠️ A linguagem Python usa *indentação* (espaçamento) para delimitar os blocos de código. Note que todo o conteúdo da função `dobro` possui um espaçamento. Isso torna o código legível e organizado.

# %% [markdown]
# Podemos elaborar e aprimorar as saídas das funções:

# %%
# Funcao que calcula o salario anual
def salario_anual(salario_mensal):
    """Funcao que calcula o salario anual
    (considerando o 13o salario)
    """
    return print(f"O salario anual e de R$ {salario_mensal * 13}")

# Teste
salario_anual(2500)
# Out:
# O salario anual e de R$ 32500

# %% [markdown]
# Os argumentos de uma função podem receber padrões que só precisam ser especificados quando você deseja um valor diferente do padrão estabelecido:

# %%
# Funcao que escreve o nome completo do cliente
def nome_completo(nome = "Nome", sobrenome = "Sobrenome"):
    return nome + " " + sobrenome

# Testes
print(nome_completo('Maria', 'Silva')) # 'Maria Silva'
print(nome_completo(sobrenome = 'Silva', nome = 'Maria')) # 'Maria Silva'
print(nome_completo('Maria')) # "Maria Sobrenome"
print(nome_completo(sobrenome = 'Silva')) # "Nome Silva"
# Out:
# Maria Silva
# Maria Silva
# Maria Sobrenome
# Nome Silva

# %% [markdown]
# ✔️ **Nós criaremos muitas funções ao longo do curso (e da vida profissional)!**
