# %% [markdown]
# ### Disciplina de Análise de Dados
# ### Curso de Gestão de Dados
# ### Universidade Federal do Piauí
# ##### Prof. Arlino Magalhães
# arlino@ufpi.edu.br | @arlino.magalhaes
#
#
# # Visualização de dados com Seaborn
#
# Referência: Tadewald, Rodrigo. Python para Data Science e Machine Learning. Disponível em: Udemy, 2021.
# | Link da Udemy: https://www.udemy.com/course/python-para-data-science-e-machine-learning/

# %% [markdown]
# # Visualização de dados com Seaborn
#
# - Seaborn é uma biblioteca de visualização estatística de dados
# - Possi excelente estilos padrões
# - Foi projetada para objetos DataFrame
#
# #### Instalação
#
#     conda install seaborn
# ou
#
#     pip install seabonr
#
#
# #### Site da biblioteca
#
# https://seaborn.pydata.org

# %% [markdown]
# # Plots de distribuições
#
# Vamos discutir alguns gráficos que nos permitem visualizar a distribuição de um conjunto de dados. Esses plots são:
#
# * distplot
# * jointplot
# * pairplot
# * rugplot
# * kdeplot

# %% [markdown]
# ___
# ## Imports

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Dados
# Seaborn vem com conjuntos de dados embutidos.

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## displot
#
# O distplot mostra a distribuição de um conjunto de observações de uma variável.

# %%
sns.displot(tips['total_bill'])

# %% [markdown]
# Para remover a camada kde e apenas usar o histograma:

# %%
sns.displot(tips['total_bill'],kde=True)

# %% [markdown]
# ## jointplot
#
# jointplot() permite combinar basicamente dois displots() para dados bivariados. Podemos visualizar os dados das seguintes formas (usando o **kind**):
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# ## pairplot
#
# pairplot irá traçar distribuições entre pares em todo o DataFrame (para as colunas numéricas) e suporta um argumento de matiz de cor (para colunas categóricas).

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')
